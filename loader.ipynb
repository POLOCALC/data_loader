# %%
from pils.loader.path import PathLoader
from pils.flight import Flight

# Set base path for filesystem-backed loader (adjust to your environment)
base_path = "/mnt/data/POLOCALC"
loader = PathLoader(base_path)

# %%
flights = loader.load_all_flights()
# Out:
# 2026-01-30 13:47:58,720 - pils.loader.path - INFO - Loading all flights from all campaigns...
# 2026-01-30 13:47:58,721 - pils.loader.path - WARNING - Could not build flight dict for calibration  /mnt/data/POLOCALC/campaigns/202412/20241215/calibration : time data 'tion ' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,749 - pils.loader.path - WARNING - Could not build flight dict for Store-V2 /mnt/data/POLOCALC/campaigns/202412/.Spotlight-V100/Store-V2: time data '2' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,751 - pils.loader.path - WARNING - Could not build flight dict for 24_12_17 /mnt/data/POLOCALC/campaigns/202412/calibration_PUC/24_12_17: time data '7' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,751 - pils.loader.path - WARNING - Could not build flight dict for 24_12_18 /mnt/data/POLOCALC/campaigns/202412/calibration_PUC/24_12_18: time data '8' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,752 - pils.loader.path - WARNING - Could not build flight dict for expunged /mnt/data/POLOCALC/campaigns/202412/.Trash-1000/expunged: time data 'd' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,752 - pils.loader.path - WARNING - Could not build flight dict for files /mnt/data/POLOCALC/campaigns/202412/.Trash-1000/files: time data '' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,752 - pils.loader.path - WARNING - Could not build flight dict for info /mnt/data/POLOCALC/campaigns/202412/.Trash-1000/info: time data '' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,771 - pils.loader.path - WARNING - Could not build flight dict for BlackSquare Test Flight /mnt/data/POLOCALC/campaigns/202504/20250502/BlackSquare Test Flight: time data 'uare Test Flight' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,774 - pils.loader.path - WARNING - Could not build flight dict for 20250424_185858 /mnt/data/POLOCALC/campaigns/202504/base/20250424_185858: time data '4_185858' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,780 - pils.loader.path - WARNING - Could not build flight dict for barycenter_cardinal_points /mnt/data/POLOCALC/campaigns/202504/flightplans/barycenter_cardinal_points: time data 'ter_cardinal_points' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,780 - pils.loader.path - WARNING - Could not build flight dict for barycenter_cardinal_points_lower /mnt/data/POLOCALC/campaigns/202504/flightplans/barycenter_cardinal_points_lower: time data 'ter_cardinal_points_lower' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,780 - pils.loader.path - WARNING - Could not build flight dict for barycenter_cardinal_points_upper /mnt/data/POLOCALC/campaigns/202504/flightplans/barycenter_cardinal_points_upper: time data 'ter_cardinal_points_upper' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,780 - pils.loader.path - WARNING - Could not build flight dict for sidelobes_satp1 /mnt/data/POLOCALC/campaigns/202504/flightplans/sidelobes_satp1: time data 'es_satp1' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,781 - pils.loader.path - WARNING - Could not build flight dict for sidelobes_satp3 /mnt/data/POLOCALC/campaigns/202504/flightplans/sidelobes_satp3: time data 'es_satp3' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,782 - pils.loader.path - WARNING - Could not build flight dict for Calibration Patterns /mnt/data/POLOCALC/campaigns/202504/20250430/Calibration Patterns: time data 'tion Patterns' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,791 - pils.loader.path - WARNING - Could not build flight dict for Flight 00 /mnt/data/POLOCALC/campaigns/202504/20250428/Flight 00: time data '00' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,814 - pils.loader.path - WARNING - Could not build flight dict for GPS Test /mnt/data/POLOCALC/campaigns/202504/20250429/GPS Test: time data 't' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,821 - pils.loader.path - WARNING - Could not build flight dict for Flight 10 /mnt/data/POLOCALC/campaigns/202504/20250425/Flight 10: time data '10' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,822 - pils.loader.path - WARNING - Could not build flight dict for Flight 09 /mnt/data/POLOCALC/campaigns/202504/20250425/Flight 09: time data '09' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,822 - pils.loader.path - WARNING - Could not build flight dict for flight_20250425_184433 /mnt/data/POLOCALC/campaigns/202504/20250425/flight_20250425_184433: unconverted data remains: 33
# 2026-01-30 13:47:58,822 - pils.loader.path - WARNING - Could not build flight dict for flight_20250425_191449 /mnt/data/POLOCALC/campaigns/202504/20250425/flight_20250425_191449: unconverted data remains: 49
# 2026-01-30 13:47:58,829 - pils.loader.path - WARNING - Could not build flight dict for Flight 05 /mnt/data/POLOCALC/campaigns/202504/20250427/Flight 05: time data '05' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,829 - pils.loader.path - WARNING - Could not build flight dict for Flight 09 /mnt/data/POLOCALC/campaigns/202504/20250427/Flight 09: time data '09' does not match format '%Y%m%d_%H%M'
# 2026-01-30 13:47:58,854 - pils.loader.path - INFO - Loaded 273 flights from filesystem
# ['202412', '202404', 'telescope_data', '202302', '202511', '202504', '202204']
# ###########
# 202412
# ================================
# 202404
# ================================
# telescope_data
# ================================
# Skip Telescope Data
# 202302
# ================================
# 202511
# ================================
# 202504
# ================================
# 202204
# ================================

# %%
flights
# Out:
# [{'campaign_name': '202412',
#   'flight_name': 'flight_20241215_1903',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T19:03:00+00:00',
#   'landing_datetime': '2024-12-15T19:03:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1903/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1903/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1903/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241215_2055',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T20:55:00+00:00',
#   'landing_datetime': '2024-12-15T20:55:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_2055/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_2055/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_2055/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241215_1357',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T13:57:00+00:00',
#   'landing_datetime': '2024-12-15T13:57:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1357/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1357/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1357/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241215_1849',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T18:49:00+00:00',
#   'landing_datetime': '2024-12-15T18:49:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1849/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1849/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1849/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241215_1730',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T17:30:00+00:00',
#   'landing_datetime': '2024-12-15T17:30:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1730/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1730/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1730/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241215_1744',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T17:44:00+00:00',
#   'landing_datetime': '2024-12-15T17:44:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1744/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1744/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1744/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241215_1415',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T14:15:00+00:00',
#   'landing_datetime': '2024-12-15T14:15:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1415/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1415/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1415/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241215_1605',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T16:05:00+00:00',
#   'landing_datetime': '2024-12-15T16:05:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1605/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1605/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1605/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241215_1433',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T14:33:00+00:00',
#   'landing_datetime': '2024-12-15T14:33:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1433/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1433/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1433/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241215_2039',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T20:39:00+00:00',
#   'landing_datetime': '2024-12-15T20:39:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_2039/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_2039/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_2039/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241215_1816',
#   'flight_date': '20241215',
#   'takeoff_datetime': '2024-12-15T18:16:00+00:00',
#   'landing_datetime': '2024-12-15T18:16:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1816/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1816/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241215/flight_20241215_1816/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241212_1448',
#   'flight_date': '20241212',
#   'takeoff_datetime': '2024-12-12T14:48:00+00:00',
#   'landing_datetime': '2024-12-12T14:48:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1448/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1448/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1448/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241212_1905',
#   'flight_date': '20241212',
#   'takeoff_datetime': '2024-12-12T19:05:00+00:00',
#   'landing_datetime': '2024-12-12T19:05:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1905/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1905/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1905/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241212_1429',
#   'flight_date': '20241212',
#   'takeoff_datetime': '2024-12-12T14:29:00+00:00',
#   'landing_datetime': '2024-12-12T14:29:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1429/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1429/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1429/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241212_1408',
#   'flight_date': '20241212',
#   'takeoff_datetime': '2024-12-12T14:08:00+00:00',
#   'landing_datetime': '2024-12-12T14:08:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1408/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1408/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_1408/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241212_2051',
#   'flight_date': '20241212',
#   'takeoff_datetime': '2024-12-12T20:51:00+00:00',
#   'landing_datetime': '2024-12-12T20:51:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_2051/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_2051/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_2051/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241212_1749',
#   'flight_date': '20241212',
#   'takeoff_datetime': '2024-12-12T17:49:00+00:00',
#   'landing_datetime': '2024-12-12T17:49:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241212/flight_20241212_
proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241211_1634',
#   'flight_date': '20241211',
#   'takeoff_datetime': '2024-12-11T16:34:00+00:00',
#   'landing_datetime': '2024-12-11T16:34:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241211/flight_20241211_1634/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241211/flight_20241211_1634/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241211/flight_20241211_1634/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241211_1453',
#   'flight_date': '20241211',
#   'takeoff_datetime': '2024-12-11T14:53:00+00:00',
#   'landing_datetime': '2024-12-11T14:53:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241211/flight_20241211_1453/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241211/flight_20241211_1453/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241211/flight_20241211_1453/proc'},
#  {'campaign_name': '202412',
#   'flight_name': 'flight_20241211_1815',
#   'flight_date': '20241211',
#   'takeoff_datetime': '2024-12-11T18:15:00+00:00',
#   'landing_datetime': '2024-12-11T18:15:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241211/flight_20241211_1815/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241211/flight_20241211_1815/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202412/20241211/flight_20241211_1815/proc'},
#  {'campaign_name': '202404',
#   'flight_name': 'flight_20240430_2006',
#   'flight_date': '20240430',
#   'takeoff_datetime': '2024-04-30T20:06:00+00:00',
#   'landing_datetime': '2024-04-30T20:06:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240430/flight_20240430_2006/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240430/flight_20240430_2006/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240430/flight_20240430_2006/proc'},
#  {'campaign_name': '202404',
#   'flight_name': 'flight_20240430_2148',
#   'flight_date': '20240430',
#   'takeoff_datetime': '2024-04-30T21:48:00+00:00',
#   'landing_datetime': '2024-04-30T21:48:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240430/flight_20240430_2148/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240430/flight_20240430_2148/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240430/flight_20240430_2148/proc'},
#  {'campaign_name': '202404',
#   'flight_name': 'flight_20240430_2041',
#   'flight_date': '20240430',
#   'takeoff_datetime': '2024-04-30T20:41:00+00:00',
#   'landing_datetime': '2024-04-30T20:41:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240430/flight_20240430_2041/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240430/flight_20240430_2041/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240430/flight_20240430_2041/proc'},
#  {'campaign_name': '202404',
#   'flight_name': 'flight_20240429_1511',
#   'flight_date': '20240429',
#   'takeoff_datetime': '2024-04-29T15:11:00+00:00',
#   'landing_datetime': '2024-04-29T15:11:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1511/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1511/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1511/proc'},
#  {'campaign_name': '202404',
#   'flight_name': 'flight_20240429_1707',
#   'flight_date': '20240429',
#   'takeoff_datetime': '2024-04-29T17:07:00+00:00',
#   'landing_datetime': '2024-04-29T17:07:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1707/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1707/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1707/proc'},
#  {'campaign_name': '202404',
#   'flight_name': 'flight_20240429_1832',
#   'flight_date': '20240429',
#   'takeoff_datetime': '2024-04-29T18:32:00+00:00',
#   'landing_datetime': '2024-04-29T18:32:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1832/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1832/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1832/proc'},
#  {'campaign_name': '202404',
#   'flight_name': 'flight_20240429_1601',
#   'flight_date': '20240429',
#   'takeoff_datetime': '2024-04-29T16:01:00+00:00',
#   'landing_datetime': '2024-04-29T16:01:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1601/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1601/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202404/20240429/flight_20240429_1601/proc'},
#  {'campaign_name': '202302',
#   'flight_name': 'flight_20230222_1226',
#   'flight_date': '20230222',
#   'takeoff_datetime': '2023-02-22T12:26:00+00:00',
#   'landing_datetime': '2023-02-22T12:26:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1226/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1226/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1226/proc'},
#  {'campaign_name': '202302',
#   'flight_name': 'flight_20230222_1522',
#   'flight_date': '20230222',
#   'takeoff_datetime': '2023-02-22T15:22:00+00:00',
#   'landing_datetime': '2023-02-22T15:22:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1522/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1522/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1522/proc'},
#  {'campaign_name': '202302',
#   'flight_name': 'flight_20230222_1118',
#   'flight_date': '20230222',
#   'takeoff_datetime': '2023-02-22T11:18:00+00:00',
#   'landing_datetime': '2023-02-22T11:18:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1118/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1118/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1118/proc'},
#  {'campaign_name': '202302',
#   'flight_name': 'flight_20230222_1352',
#   'flight_date': '20230222',
#   'takeoff_datetime': '2023-02-22T13:52:00+00:00',
#   'landing_datetime': '2023-02-22T13:52:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1352/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1352/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_1352/proc'},
#  {'campaign_name': '202302',
#   'flight_name': 'flight_20230222_1035',
#   'flight_date': '20230222',
#   'takeoff_datetime': '2023-02-22T10:35:00+00:00',
#   'landing_datetime': '2023-02-22T10:35:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202302/20230222/flight_20230222_
aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202504/20250427/flight_20250427_1422/proc'},
#  {'campaign_name': '202504',
#   'flight_name': 'flight_20250427_1832',
#   'flight_date': '20250427',
#   'takeoff_datetime': '2025-04-27T18:32:00+00:00',
#   'landing_datetime': '2025-04-27T18:32:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202504/20250427/flight_20250427_1832/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202504/20250427/flight_20250427_1832/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202504/20250427/flight_20250427_1832/proc'},
#  {'campaign_name': '202204',
#   'flight_name': 'flight_20220426_2056',
#   'flight_date': '20220426',
#   'takeoff_datetime': '2022-04-26T20:56:00+00:00',
#   'landing_datetime': '2022-04-26T20:56:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220426/flight_20220426_2056/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220426/flight_20220426_2056/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220426/flight_20220426_2056/proc'},
#  {'campaign_name': '202204',
#   'flight_name': 'flight_20220426_1710',
#   'flight_date': '20220426',
#   'takeoff_datetime': '2022-04-26T17:10:00+00:00',
#   'landing_datetime': '2022-04-26T17:10:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220426/flight_20220426_1710/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220426/flight_20220426_1710/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220426/flight_20220426_1710/proc'},
#  {'campaign_name': '202204',
#   'flight_name': 'flight_20220427_1802',
#   'flight_date': '20220427',
#   'takeoff_datetime': '2022-04-27T18:02:00+00:00',
#   'landing_datetime': '2022-04-27T18:02:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220427/flight_20220427_1802/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220427/flight_20220427_1802/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220427/flight_20220427_1802/proc'},
#  {'campaign_name': '202204',
#   'flight_name': 'flight_20220427_1848',
#   'flight_date': '20220427',
#   'takeoff_datetime': '2022-04-27T18:48:00+00:00',
#   'landing_datetime': '2022-04-27T18:48:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220427/flight_20220427_1848/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220427/flight_20220427_1848/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220427/flight_20220427_1848/proc'},
#  {'campaign_name': '202204',
#   'flight_name': 'flight_20220429_1402',
#   'flight_date': '20220429',
#   'takeoff_datetime': '2022-04-29T14:02:00+00:00',
#   'landing_datetime': '2022-04-29T14:02:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1402/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1402/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1402/proc'},
#  {'campaign_name': '202204',
#   'flight_name': 'flight_20220429_1813',
#   'flight_date': '20220429',
#   'takeoff_datetime': '2022-04-29T18:13:00+00:00',
#   'landing_datetime': '2022-04-29T18:13:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1813/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1813/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1813/proc'},
#  {'campaign_name': '202204',
#   'flight_name': 'flight_20220429_1927',
#   'flight_date': '20220429',
#   'takeoff_datetime': '2022-04-29T19:27:00+00:00',
#   'landing_datetime': '2022-04-29T19:27:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1927/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1927/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1927/proc'},
#  {'campaign_name': '202204',
#   'flight_name': 'flight_20220429_1519',
#   'flight_date': '20220429',
#   'takeoff_datetime': '2022-04-29T15:19:00+00:00',
#   'landing_datetime': '2022-04-29T15:19:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1519/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1519/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1519/proc'},
#  {'campaign_name': '202204',
#   'flight_name': 'flight_20220429_1652',
#   'flight_date': '20220429',
#   'takeoff_datetime': '2022-04-29T16:52:00+00:00',
#   'landing_datetime': '2022-04-29T16:52:00+00:00',
#   'drone_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1652/drone',
#   'aux_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1652/aux',
#   'processed_data_folder_path': '/mnt/data/POLOCALC/campaigns/202204/20220429/flight_20220429_1652/proc'}]

# %% [markdown]
# # STOUT LOADER

# %%
from pils.loader.stout import StoutLoader
from pils.flight import Flight

# DB-backed loader (requires stout config and DB access)
stout_loader = StoutLoader()

flight_meta = stout_loader.load_single_flight(flight_id="e809e9fe-0dcb-4a70-8300-ac9dceb99d3f")

flight = Flight(flight_meta)
# Out:
# 2026-01-30 14:45:46.710 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 14:45:46 - stout - WARNING - [authenticated_user] - Cannot write to log directory /mnt/data/POLOCALC/logs: [Errno 13] Permission denied: '/mnt/data/POLOCALC/logs/stout.log'. Using console logging only.
# 2026-01-30 14:45:46,390 - stout - WARNING - Cannot write to log directory /mnt/data/POLOCALC/logs: [Errno 13] Permission denied: '/mnt/data/POLOCALC/logs/stout.log'. Using console logging only.
# 2026-01-30 14:45:46.711 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-01-30 14:45:46 - stout - INFO - [authenticated_user] - Centralized logging system initialized
# 2026-01-30 14:45:46,712 - pils.loader.stout - INFO - Initialized with stout database, base path: /mnt/data/POLOCALC
# 2026-01-30 14:45:46,712 - pils.loader.stout - INFO - Loading single flight: flight_id=e809e9fe-0dcb-4a70-8300-ac9dceb99d3f, flight_name=None
# 2026-01-30 14:45:46,735 - pils.loader.stout - INFO - Loaded flight: flight_20251201_1515

# %%
flight.add_sensor_data(['gps', 'inclinometer'])
# Out:
# {'hAcc': 671, 'hMSL': 5147920, 'height': 5179382, 'iTOW': 141996000, 'lat': -22.95973, 'lon': -67.7869096, 'msgmode': 0, 'vAcc': 1200}
# Sensor Type imx5

# %%
flight.raw_data['payload']['inclinometer']['IMU'].columns
# Out:
# ['monotonic_ns',
#  'timestamp_ns',
#  'time_s',
#  'status',
#  'pqr_P_rad_s',
#  'pqr_Q_rad_s',
#  'pqr_R_rad_s',
#  'acc_X_m_s2',
#  'acc_Y_m_s2',
#  'acc_Z_m_s2',
#  'timestamp',
#  'datetime',
#  'pqr_P_deg_s',
#  'pqr_Q_deg_s',
#  'pqr_R_deg_s']

# %%
plt.figure()
plt.plot(flight.raw_data['payload']['inclinometer']['IMU']['acc_Z_m_s2'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flight.add_drone_data()
# Out:
# 2026-01-30 15:04:27,564 - pils.drones.DJIDrone - INFO - Tick unwrap at index 4009: 4,294,296,476 -> 206,394 (adding offset 2^32, total offset: 4,294,967,296)
# 2026-01-30 15:04:27,566 - pils.drones.DJIDrone - INFO - Loaded 7114 GPS messages from DAT file
# 2026-01-30 15:04:27,582 - pils.drones.DJIDrone - INFO - Tick unwrap at index 3705: 4,294,110,891 -> 43,735 (adding offset 2^32, total offset: 4,294,967,296)
# 2026-01-30 15:04:27,583 - pils.drones.DJIDrone - INFO - Loaded 6625 RTK messages from DAT file
# 2026-01-30 15:04:27,751 - pils.drones.DJIDrone - INFO - Converting timestamps to milliseconds
# Drone:
# shape: (13_608, 43)
# ┌────────────┬──────────┬───────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ tick       ┆ msg_type ┆ GPS:date  ┆ GPS:time ┆ … ┆ RTK:pos_f ┆ RTK:pos_f ┆ RTK:pos_f ┆ RTK:gps_s │
# │ ---        ┆ ---      ┆ ---       ┆ ---      ┆   ┆ lg_3      ┆ lg_4      ┆ lg_5      ┆ tate      │
# │ i64        ┆ i64      ┆ f64       ┆ f64      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆          ┆           ┆          ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪══════════╪═══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 90722730   ┆ 53234    ┆ null      ┆ null     ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0       │
# │ 91712457   ┆ 53234    ┆ null      ┆ null     ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0       │
# │ 92612599   ┆ 53234    ┆ null      ┆ null     ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0       │
# │ 93602073   ┆ 53234    ┆ null      ┆ null     ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0       │
# │ 94322836   ┆ 53234    ┆ null      ┆ null     ┆ … ┆ 0.0       ┆ 0.0       ┆ 0.0       ┆ 0.0       │
# │ …          ┆ …        ┆ …         ┆ …        ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 7595159065 ┆ 53234    ┆ 2.0251201 ┆ 152705.0 ┆ … ┆ 50.0      ┆ 50.0      ┆ 0.0       ┆ 0.0       │
# │            ┆          ┆ e7        ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 7595404940 ┆ 2096     ┆ 2.0251201 ┆ 152705.0 ┆ … ┆ 50.0      ┆ 50.0      ┆ 0.0       ┆ 0.0       │
# │            ┆          ┆ e7        ┆          ┆   ┆           ┆           ┆           ┆           │
# │ 7596059179 ┆ 53234    ┆ null      ┆ null     ┆ … ┆ 50.0      ┆ 50.0      ┆ 0.0       ┆ 0.0       │
# │ 7726762966 ┆ 53234    ┆ null      ┆ null     ┆ … ┆ 162.0     ┆ 238.0     ┆ 91.0      ┆ 23325.0   │
# │ 7731186352 ┆ 53234    ┆ null      ┆ null     ┆ … ┆ 196.0     ┆ 117.0     ┆ 62.0      ┆ 15706.0   │
# └────────────┴──────────┴───────────┴──────────┴───┴───────────┴───────────┴───────────┴───────────┘
#
# Litchi:
# shape: (5_906, 20)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ latitude  ┆ longitude ┆ altitude( ┆ speed(mps ┆ … ┆ gimbalPit ┆ gimbalRol ┆ gimbalYaw ┆ datetime │
# │ ---       ┆ ---       ┆ m)        ┆ )         ┆   ┆ chRaw     ┆ lRaw      ┆ Raw       ┆ ---      │
# │ f64       ┆ f64       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ datetime │
# │           ┆           ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ f64       ┆ [μs]     │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ -22.95974 ┆ -67.78691 ┆ 0.5       ┆ 0.82      ┆ … ┆ 0.0       ┆ 0.0       ┆ 7.0       ┆ 2025-12- │
# │ 2         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01 15:15 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ :17.994  │
# │ -22.95974 ┆ -67.78691 ┆ 0.5       ┆ 0.73      ┆ … ┆ 1.0       ┆ 0.0       ┆ 7.0       ┆ 2025-12- │
# │ 2         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01 15:15 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ :18.100  │
# │ -22.95974 ┆ -67.78691 ┆ 0.6       ┆ 0.71      ┆ … ┆ 2.0       ┆ 0.0       ┆ 7.0       ┆ 2025-12- │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01 15:15 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ :18.184  │
# │ -22.95974 ┆ -67.78691 ┆ 0.7       ┆ 0.61      ┆ … ┆ 0.0       ┆ 0.0       ┆ 7.0       ┆ 2025-12- │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01 15:15 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ :18.289  │
# │ -22.95974 ┆ -67.78691 ┆ 0.7       ┆ 0.51      ┆ … ┆ 0.0       ┆ 0.0       ┆ 7.0       ┆ 2025-12- │
# │ 3         ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01 15:15 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ :18.390  │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ -22.95974 ┆ -67.78691 ┆ 0.0       ┆ 0.0       ┆ … ┆ -27.0     ┆ 0.0       ┆ 45.0      ┆ 2025-12- │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01 15:26 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ :03.160  │
# │ -22.95974 ┆ -67.78691 ┆ 0.0       ┆ 0.0       ┆ … ┆ -19.0     ┆ 0.0       ┆ 45.0      ┆ 2025-12- │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01 15:26 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ :03.264  │
# │ -22.95974 ┆ -67.78691 ┆ 0.0       ┆ 0.0       ┆ … ┆ -20.0     ┆ 0.0       ┆ 46.0      ┆ 2025-12- │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01 15:26 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ :03.364  │
# │ -22.95974 ┆ -67.78691 ┆ 0.0       ┆ 0.0       ┆ … ┆ -21.0     ┆ 0.0       ┆ 45.0      ┆ 2025-12- │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01 15:26 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ :03.467  │
# │ -22.95974 ┆ -67.78691 ┆ 0.0       ┆ 0.0       ┆ … ┆ -21.0     ┆ 0.0       ┆ 46.0      ┆ 2025-12- │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆           ┆ 01 15:26 │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ :03.568  │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
import polars as pl
flight.raw_data.drone_data.litchi = flight.raw_data.drone_data.litchi.with_columns((pl.col("datetime").dt.timestamp("ms")).alias("unix_timestamp [ms]"))

# %%
import numpy as np
plt.figure()

# plt.plot(flight.raw_data.drone_data.drone["correct_timestamp"], flight.raw_data.drone_data.drone["RTK:yaw"], label = 'DJI')
plt.plot(flight.raw_data.drone_data.litchi["unix_timestamp [ms]"]/1e3, flight.raw_data.drone_data.litchi["yaw(deg)"], label='Litchi')
plt.plot(flight.raw_data.payload_data['inclinometer']['INS']['timestamp_ns']/1e9, np.degrees(flight.raw_data.payload_data['inclinometer']['INS']['yaw_rad']), label='Incl')
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flight.raw_data.drone_data.litchi.columns
# Out:
# ['latitude',
#  'longitude',
#  'altitude(m)',
#  'speed(mps)',
#  'distance(m)',
#  'velocityX(mps)',
#  'velocityY(mps)',
#  'velocityZ(mps)',
#  'pitch(deg)',
#  'roll(deg)',
#  'yaw(deg)',
#  'isflying',
#  'batteryTemperature',
#  'pitchRaw',
#  'rollRaw',
#  'yawRaw',
#  'gimbalPitchRaw',
#  'gimbalRollRaw',
#  'gimbalYawRaw',
#  'datetime']

# %%
plt.figure()

plt.plot(flight.raw_data.drone_data.drone["correct_timestamp"], flight.raw_data.drone_data.drone["GPS:latitude"], label = 'DJI')
plt.plot(flight.raw_data.drone_data.litchi["unix_timestamp [ms]"]/1e3, flight.raw_data.drone_data.litchi["latitude"], label='UBLOX')
plt.plot(flight.raw_data.payload_data.gps['unix_time_ms']/1e3,flight.raw_data.payload_data.gps['posllh_lat'], label='Litchi')
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flight.raw_data.drone_data.litchi = flight.raw_data.drone_data.litchi.with_columns((pl.col("datetime").dt.timestamp("ms")).alias("unix_timestamp [ms]"))

# %%
import polars as pl
flight.raw_data.drone_data.litchi.with_columns((pl.col("datetime").dt.timestamp("ms")).alias("unix_timestamp [ms]"))
# Out:
# shape: (5_906, 21)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ latitude  ┆ longitude ┆ altitude( ┆ speed(mps ┆ … ┆ gimbalRol ┆ gimbalYaw ┆ datetime  ┆ unix_tim │
# │ ---       ┆ ---       ┆ m)        ┆ )         ┆   ┆ lRaw      ┆ Raw       ┆ ---       ┆ estamp   │
# │ f64       ┆ f64       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ datetime[ ┆ [ms]     │
# │           ┆           ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ μs]       ┆ ---      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆           ┆ i64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ -22.95974 ┆ -67.78691 ┆ 0.5       ┆ 0.82      ┆ … ┆ 0.0       ┆ 7.0       ┆ 2025-12-0 ┆ 17646021 │
# │ 2         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆ 1 15:15:1 ┆ 17994    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 7.994     ┆          │
# │ -22.95974 ┆ -67.78691 ┆ 0.5       ┆ 0.73      ┆ … ┆ 0.0       ┆ 7.0       ┆ 2025-12-0 ┆ 17646021 │
# │ 2         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆ 1 15:15:1 ┆ 18100    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 8.100     ┆          │
# │ -22.95974 ┆ -67.78691 ┆ 0.6       ┆ 0.71      ┆ … ┆ 0.0       ┆ 7.0       ┆ 2025-12-0 ┆ 17646021 │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆ 1 15:15:1 ┆ 18184    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 8.184     ┆          │
# │ -22.95974 ┆ -67.78691 ┆ 0.7       ┆ 0.61      ┆ … ┆ 0.0       ┆ 7.0       ┆ 2025-12-0 ┆ 17646021 │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆ 1 15:15:1 ┆ 18289    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 8.289     ┆          │
# │ -22.95974 ┆ -67.78691 ┆ 0.7       ┆ 0.51      ┆ … ┆ 0.0       ┆ 7.0       ┆ 2025-12-0 ┆ 17646021 │
# │ 3         ┆ 7         ┆           ┆           ┆   ┆           ┆           ┆ 1 15:15:1 ┆ 18390    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 8.390     ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ -22.95974 ┆ -67.78691 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 45.0      ┆ 2025-12-0 ┆ 17646027 │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆ 1 15:26:0 ┆ 63160    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 3.160     ┆          │
# │ -22.95974 ┆ -67.78691 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 45.0      ┆ 2025-12-0 ┆ 17646027 │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆ 1 15:26:0 ┆ 63264    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 3.264     ┆          │
# │ -22.95974 ┆ -67.78691 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 46.0      ┆ 2025-12-0 ┆ 17646027 │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆ 1 15:26:0 ┆ 63364    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 3.364     ┆          │
# │ -22.95974 ┆ -67.78691 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 45.0      ┆ 2025-12-0 ┆ 17646027 │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆ 1 15:26:0 ┆ 63467    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 3.467     ┆          │
# │ -22.95974 ┆ -67.78691 ┆ 0.0       ┆ 0.0       ┆ … ┆ 0.0       ┆ 46.0      ┆ 2025-12-0 ┆ 17646027 │
# │ 3         ┆ 8         ┆           ┆           ┆   ┆           ┆           ┆ 1 15:26:0 ┆ 63568    │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 3.568     ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
def get_true_offset(t_ref, y_ref, t_target, y_target):
    # 1. Resample target to the reference clock
    f = interp1d(t_target, y_target, kind='linear', fill_value="extrapolate")
    y_target_res = f(t_ref)
    
    # 2. CALCULATE DERIVATIVES (The Magic Step)
    # This removes the global downward trend seen in your Figure 6
    dy_ref = np.diff(y_ref)
    dy_target = np.diff(y_target_res)
    
    # 3. Standardize the derivatives (Z-score)
    # This ensures different signal magnitudes don't bias the result
    dy_ref = (dy_ref - np.mean(dy_ref)) / np.std(dy_ref)
    dy_target = (dy_target - np.mean(dy_target)) / np.std(dy_target)
    
    # 4. Cross-Correlate the derivatives
    correlation = correlate(dy_ref, dy_target, mode='full')
    lags = correlation_lags(len(dy_ref), len(dy_target), mode='full')
    
    # 5. Find the peak
    best_lag_idx = lags[np.argmax(correlation)]
    dt = t_ref[1] - t_ref[0]
    
    return best_lag_idx * dt

tau2 = get_true_offset(flight.raw_data.payload_data.gps['unix_time_ms']/1e3, 
                   flight.raw_data.payload_data.gps['posllh_lat'], 
                   flight.raw_data.drone_data.drone["correct_timestamp"], 
                   flight.raw_data.drone_data.drone["GPS:latitude"])
tau3 = get_true_offset(flight.raw_data.payload_data.gps['unix_time_ms']/1e3, 
                   flight.raw_data.payload_data.gps['posllh_lat'], 
                   flight.raw_data.drone_data.litchi["unix_timestamp [ms]"]/1e3,
                   flight.raw_data.drone_data.litchi["latitude"])

print(f"Offset for Curve 2: {tau2:.3f}s")
print(f"Offset for Curve 3: {tau3:.3f}s")
# Out:
# Offset for Curve 2: 0.500s
# Offset for Curve 3: 0.000s

# %%
import numpy as np
from scipy import signal
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

def lla_to_enu(lat, lon, alt, lat_ref, lon_ref, alt_ref):
    """
    Convert latitude, longitude, altitude to local ENU (East-North-Up) coordinates.
    
    Parameters:
    -----------
    lat, lon, alt : arrays of latitude (deg), longitude (deg), altitude (m)
    lat_ref, lon_ref, alt_ref : reference point for local frame
    
    Returns:
    --------
    east, north, up : arrays in meters
    """
    # Earth radius in meters
    R = 6378137.0
    
    # Convert to radians
    lat_rad = np.radians(lat)
    lon_rad = np.radians(lon)
    lat_ref_rad = np.radians(lat_ref)
    lon_ref_rad = np.radians(lon_ref)
    
    # Compute ENU
    dlon = lon_rad - lon_ref_rad
    dlat = lat_rad - lat_ref_rad
    
    # Approximate for small distances
    east = R * dlon * np.cos(lat_ref_rad)
    north = R * dlat
    up = alt - alt_ref
    
    return east, north, up

def find_subsample_peak(correlation, lags, dt):
    """
    Find sub-sample peak using parabolic interpolation.
    
    Returns:
    --------
    Refined time offset with sub-sample precision
    """
    max_idx = np.argmax(correlation)
    
    # Need at least one sample on each side for interpolation
    if max_idx == 0 or max_idx == len(correlation) - 1:
        return lags[max_idx] * dt
    
    # Parabolic interpolation using three points around peak
    y1, y2, y3 = correlation[max_idx-1:max_idx+2]
    
    # Check for valid parabola (avoid division by zero)
    denominator = y1 - 2*y2 + y3
    if abs(denominator) < 1e-10:
        return lags[max_idx] * dt
    
    # Vertex of parabola through these three points
    delta = 0.5 * (y1 - y3) / denominator
    
    # Refined peak location
    refined_lag = lags[max_idx] + delta
    refined_offset = refined_lag * dt
    
    return refined_offset

def find_gps_offset(time1, lat1, lon1, alt1, time2, lat2, lon2, alt2, 
                    axis_names=['East', 'North', 'Up']):
    """
    Find time and spatial offset between two GPS sensors.
    
    Parameters:
    -----------
    time1, time2 : array-like, timestamps for each sensor (in seconds)
    lat1, lon1, alt1 : arrays for sensor 1 (latitude in deg, longitude in deg, altitude in m)
    lat2, lon2, alt2 : arrays for sensor 2
    axis_names : list of axis labels for reporting
    
    Returns:
    --------
    dict with 'time_offset' (in seconds) and 'spatial_offset' (3D vector in meters [E, N, U])
    """
    
    # Convert to numpy arrays
    time1 = np.array(time1)
    lat1 = np.array(lat1)
    lon1 = np.array(lon1)
    alt1 = np.array(alt1)
    
    time2 = np.array(time2)
    lat2 = np.array(lat2)
    lon2 = np.array(lon2)
    alt2 = np.array(alt2)
    
    # Choose reference point (use first point of sensor 1)
    lat_ref = lat1[0]
    lon_ref = lon1[0]
    alt_ref = alt1[0]
    
    print(f"Reference point: lat={lat_ref:.6f}°, lon={lon_ref:.6f}°, alt={alt_ref:.2f}m")
    
    # Convert both to ENU coordinates
    east1, north1, up1 = lla_to_enu(lat1, lon1, alt1, lat_ref, lon_ref, alt_ref)
    east2, north2, up2 = lla_to_enu(lat2, lon2, alt2, lat_ref, lon_ref, alt_ref)
    
    pos1 = np.column_stack([east1, north1, up1])
    pos2 = np.column_stack([east2, north2, up2])
    
    print(f"\nSensor 1: {len(time1)} samples, rate ~{1/np.median(np.diff(time1)):.2f} Hz")
    print(f"Sensor 2: {len(time2)} samples, rate ~{1/np.median(np.diff(time2)):.2f} Hz")
    
    # Determine common time base (use the higher frequency sensor's rate)
    dt1 = np.median(np.diff(time1))
    dt2 = np.median(np.diff(time2))
    dt_common = min(dt1, dt2)
    
    print(f"Common sampling interval: {dt_common:.4f} s ({1/dt_common:.2f} Hz)")
    
    # Create common time vector spanning the overlap
    t_start = max(time1[0], time2[0])
    t_end = min(time1[-1], time2[-1])
    time_common = np.arange(t_start, t_end, dt_common)
    
    print(f"Overlap duration: {t_end - t_start:.2f} s")
    
    # Interpolate both signals to common timebase
    pos1_interp = np.zeros((len(time_common), 3))
    pos2_interp = np.zeros((len(time_common), 3))
    
    for i in range(3):
        f1 = interp1d(time1, pos1[:, i], kind='linear', bounds_error=False, fill_value='extrapolate')
        f2 = interp1d(time2, pos2[:, i], kind='linear', bounds_error=False, fill_value='extrapolate')
        pos1_interp[:, i] = f1(time_common)
        pos2_interp[:, i] = f2(time_common)
    
    # Compute cross-correlation for each axis
    time_offsets = []
    correlations = []
    
    print("\n" + "="*60)
    print("Cross-correlation analysis:")
    print("="*60)
    
    for i, axis_name in enumerate(axis_names):
        corr = signal.correlate(pos1_interp[:, i], pos2_interp[:, i], mode='full')
        lags = signal.correlation_lags(len(pos1_interp[:, i]), len(pos2_interp[:, i]), mode='full')
        
        # Find peak with sub-sample precision
        time_offset_seconds = find_subsample_peak(corr, lags, dt_common)
        
        time_offsets.append(time_offset_seconds)
        correlations.append(np.max(corr))
        
        print(f"{axis_name:5s}-axis: offset = {time_offset_seconds:+8.4f} s, correlation = {np.max(corr):.2e}")
    
    # Use weighted average of time offsets (weighted by correlation strength)
    correlations = np.array(correlations)
    time_offsets = np.array(time_offsets)
    weights = correlations / np.sum(correlations)
    final_time_offset = np.sum(time_offsets * weights)
    
    print("="*60)
    print(f"Weighted average time offset: {final_time_offset:+.4f} s")
    print(f"  (Sensor 2 is {'ahead' if final_time_offset > 0 else 'behind'} Sensor 1)")
    print("="*60)
    
    # Now time-align and compute spatial offset
    # Shift sensor 2 by the detected offset
    time2_aligned = time2 + final_time_offset
    
    # Re-interpolate to find spatial offset
    pos2_aligned = np.zeros((len(time1), 3))
    for i in range(3):
        f2 = interp1d(time2_aligned, pos2[:, i], kind='linear', 
                     bounds_error=False, fill_value='extrapolate')
        pos2_aligned[:, i] = f2(time1)
    
    # Compute spatial offset (mean difference)
    spatial_offset = np.mean(pos1 - pos2_aligned, axis=0)
    
    print(f"\nSpatial offset (Sensor1 - Sensor2):")
    print(f"  East:  {spatial_offset[0]:+8.4f} m")
    print(f"  North: {spatial_offset[1]:+8.4f} m")
    print(f"  Up:    {spatial_offset[2]:+8.4f} m")
    print(f"  Horizontal distance: {np.sqrt(spatial_offset[0]**2 + spatial_offset[1]**2):.4f} m")
    print(f"  3D distance: {np.linalg.norm(spatial_offset):.4f} m")
    
    return {
        'time_offset': final_time_offset,
        'time_offsets_per_axis': time_offsets,
        'correlations': correlations,
        'spatial_offset': spatial_offset,
        'spatial_offset_enu': {'east': spatial_offset[0], 
                               'north': spatial_offset[1], 
                               'up': spatial_offset[2]},
        'dt_common': dt_common,
        'pos1_enu': pos1,
        'pos2_enu': pos2,
        'time1': time1,
        'time2': time2
    }

def plot_alignment(result):
    """
    Visualize the GPS alignment results.
    
    Parameters:
    -----------
    result : dict returned from find_gps_offset
    """
    pos1 = result['pos1_enu']
    pos2 = result['pos2_enu']
    time1 = result['time1']
    time2 = result['time2']
    time_offset = result['time_offset']
    spatial_offset = result['spatial_offset']
    
    # Apply corrections to sensor 2
    time2_corrected = time2 + time_offset
    pos2_corrected = pos2 + spatial_offset
    
    # Interpolate sensor 2 to sensor 1 timestamps for comparison
    pos2_interp = np.zeros_like(pos1)
    for i in range(3):
        f = interp1d(time2_corrected, pos2_corrected[:, i], kind='linear',
                    bounds_error=False, fill_value='extrapolate')
        pos2_interp[:, i] = f(time1)
    
    fig, axes = plt.subplots(3, 2, figsize=(14, 10))
    axis_names = ['East', 'North', 'Up']
    
    for i, name in enumerate(axis_names):
        # Before correction
        axes[i, 0].plot(time1, pos1[:, i], 'b-', label='Sensor 1', alpha=0.7)
        axes[i, 0].plot(time2, pos2[:, i], 'r-', label='Sensor 2 (raw)', alpha=0.7)
        axes[i, 0].set_ylabel(f'{name} (m)')
        axes[i, 0].legend()
        axes[i, 0].grid(True, alpha=0.3)
        axes[i, 0].set_title(f'{name} - Before Correction')
        
        # After correction
        axes[i, 1].plot(time1, pos1[:, i], 'b-', label='Sensor 1', alpha=0.7)
        axes[i, 1].plot(time1, pos2_interp[:, i], 'g-', label='Sensor 2 (corrected)', alpha=0.7)
        axes[i, 1].set_ylabel(f'{name} (m)')
        axes[i, 1].legend()
        axes[i, 1].grid(True, alpha=0.3)
        axes[i, 1].set_title(f'{name} - After Correction')
    
    axes[2, 0].set_xlabel('Time (s)')
    axes[2, 1].set_xlabel('Time (s)')
    
    plt.tight_layout()
    plt.show()
    
    # 3D trajectory plot
    fig = plt.figure(figsize=(12, 5))
    
    ax1 = fig.add_subplot(121, projection='3d')
    ax1.plot(pos1[:, 0], pos1[:, 1], pos1[:, 2], 'b-', label='Sensor 1', linewidth=2)
    ax1.plot(pos2[:, 0], pos2[:, 1], pos2[:, 2], 'r-', label='Sensor 2 (raw)', linewidth=2, alpha=0.7)
    ax1.set_xlabel('East (m)')
    ax1.set_ylabel('North (m)')
    ax1.set_zlabel('Up (m)')
    ax1.legend()
    ax1.set_title('3D Trajectory - Before Correction')
    
    ax2 = fig.add_subplot(122, projection='3d')
    ax2.plot(pos1[:, 0], pos1[:, 1], pos1[:, 2], 'b-', label='Sensor 1', linewidth=2)
    ax2.plot(pos2_corrected[:, 0], pos2_corrected[:, 1], pos2_corrected[:, 2], 
             'g-', label='Sensor 2 (corrected)', linewidth=2, alpha=0.7)
    ax2.set_xlabel('East (m)')
    ax2.set_ylabel('North (m)')
    ax2.set_zlabel('Up (m)')
    ax2.legend()
    ax2.set_title('3D Trajectory - After Correction')
    
    plt.tight_layout()
    plt.show()

# Example usage:
if __name__ == "__main__":
    # Example with synthetic data - replace with your real data
    
    print("="*60)
    print("GPS OFFSET FINDER")
    print("="*60)
    print(f"True time offset: {time_offset_true} s")
    print(f"True spatial offset: {spatial_offset_true} m (ENU)")
    print()
    
    # Find the offset
    result = find_gps_offset(flight.raw_data.payload_data.gps['unix_time_ms']/1e3, 
                             flight.raw_data.payload_data.gps['posllh_lat'], 
                             flight.raw_data.payload_data.gps['posllh_lon'], 
                             flight.raw_data.payload_data.gps['posllh_height']/1e3, 
                             flight.raw_data.drone_data.drone["correct_timestamp"], 
                             flight.raw_data.drone_data.drone["GPS:latitude"], 
                             flight.raw_data.drone_data.drone["GPS:longitude"], 
                             flight.raw_data.drone_data.drone["GPS:heightMSL"])
    
    print("\n" + "="*60)
    print("ERROR ANALYSIS")
    print("="*60)
    print(f"Time offset error: {abs(result['time_offset'] - time_offset_true):.4f} s")
    print(f"Spatial offset error: {np.linalg.norm(result['spatial_offset'] - spatial_offset_true):.4f} m")
    
    # Plot results
    plot_alignment(result)
# Out:
# ============================================================
# GPS OFFSET FINDER
# ============================================================
# True time offset: 0.35 s
# True spatial offset: [ 2.5 -1.8  0.5] m (ENU)
#
# Reference point: lat=-22.959743°, lon=-67.786937°, alt=5181.11m
#
# Sensor 1: 1439 samples, rate ~2.00 Hz
# Sensor 2: 13608 samples, rate ~nan Hz
# Common sampling interval: 0.5000 s (2.00 Hz)
# Overlap duration: 719.00 s
#
# ============================================================
# Cross-correlation analysis:
# ============================================================
# East -axis: offset =  +0.5204 s, correlation = 1.73e+07
# North-axis: offset =  +0.5655 s, correlation = 1.10e+08
# Up   -axis: offset =  +1.0037 s, correlation = 9.78e+07
# ============================================================
# Weighted average time offset: +0.7525 s
#   (Sensor 2 is ahead Sensor 1)
# ============================================================
#
# Spatial offset (Sensor1 - Sensor2):
#   East:   +0.8281 m
#   North:  -0.0668 m
#   Up:    +30.9166 m
#   Horizontal distance: 0.8308 m
#   3D distance: 30.9277 m
#
# ============================================================
# ERROR ANALYSIS
# ============================================================
# Time offset error: 0.4025 s
# Spatial offset error: 30.5117 m
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flight.raw_data.payload_data.gps['posllh_height']
# Out:
# shape: (1_439,)
# Series: 'posllh_height' [i64]
# [
# 	5181113
# 	5181147
# 	5181187
# 	5181225
# 	5181265
# 	…
# 	5179384
# 	5179380
# 	5179381
# 	5179383
# 	5179382
# ]

# %%
flight.raw_data.payload_data.gps
# Out:
# shape: (1_439, 21)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ unix_time ┆ posecef_e ┆ posecef_e ┆ posecef_e ┆ … ┆ clock_msg ┆ clock_tAc ┆ datetime  ┆ timestam │
# │ _ms       ┆ cefX      ┆ cefY      ┆ cefZ      ┆   ┆ mode      ┆ c         ┆ ---       ┆ p        │
# │ ---       ┆ ---       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ datetime[ ┆ ---      │
# │ i64       ┆ i64       ┆ i64       ┆ i64       ┆   ┆ i64       ┆ i64       ┆ ms]       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 176460205 ┆ 222317927 ┆ -54441861 ┆ -24746360 ┆ … ┆ 0         ┆ 11        ┆ 2025-12-0 ┆ 1.7646e9 │
# │ 9000      ┆           ┆ 6         ┆ 1         ┆   ┆           ┆           ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 15:14:19  ┆          │
# │ 176460205 ┆ 222317931 ┆ -54441861 ┆ -24746360 ┆ … ┆ 0         ┆ 11        ┆ 2025-12-0 ┆ 1.7646e9 │
# │ 9500      ┆           ┆ 7         ┆ 3         ┆   ┆           ┆           ┆ 1 15:14:1 ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 9.500     ┆          │
# │ 176460206 ┆ 222317934 ┆ -54441862 ┆ -24746360 ┆ … ┆ 0         ┆ 10        ┆ 2025-12-0 ┆ 1.7646e9 │
# │ 0000      ┆           ┆ 0         ┆ 5         ┆   ┆           ┆           ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 15:14:20  ┆          │
# │ 176460206 ┆ 222317937 ┆ -54441862 ┆ -24746360 ┆ … ┆ 0         ┆ 10        ┆ 2025-12-0 ┆ 1.7646e9 │
# │ 0500      ┆           ┆ 2         ┆ 7         ┆   ┆           ┆           ┆ 1 15:14:2 ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 0.500     ┆          │
# │ 176460206 ┆ 222317940 ┆ -54441862 ┆ -24746360 ┆ … ┆ 0         ┆ 10        ┆ 2025-12-0 ┆ 1.7646e9 │
# │ 1000      ┆           ┆ 5         ┆ 9         ┆   ┆           ┆           ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 15:14:21  ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 176460277 ┆ 222318151 ┆ -54441841 ┆ -24746339 ┆ … ┆ 0         ┆ 3         ┆ 2025-12-0 ┆ 1.7646e9 │
# │ 6000      ┆           ┆ 4         ┆ 9         ┆   ┆           ┆           ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 15:26:16  ┆          │
# │ 176460277 ┆ 222318151 ┆ -54441841 ┆ -24746339 ┆ … ┆ 0         ┆ 3         ┆ 2025-12-0 ┆ 1.7646e9 │
# │ 6500      ┆           ┆ 4         ┆ 9         ┆   ┆           ┆           ┆ 1 15:26:1 ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 6.500     ┆          │
# │ 176460277 ┆ 222318151 ┆ -54441841 ┆ -24746339 ┆ … ┆ 0         ┆ 3         ┆ 2025-12-0 ┆ 1.7646e9 │
# │ 7000      ┆           ┆ 4         ┆ 8         ┆   ┆           ┆           ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 15:26:17  ┆          │
# │ 176460277 ┆ 222318151 ┆ -54441841 ┆ -24746339 ┆ … ┆ 0         ┆ 3         ┆ 2025-12-0 ┆ 1.7646e9 │
# │ 7500      ┆           ┆ 4         ┆ 8         ┆   ┆           ┆           ┆ 1 15:26:1 ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 7.500     ┆          │
# │ 176460277 ┆ 222318151 ┆ -54441841 ┆ -24746339 ┆ … ┆ 0         ┆ 3         ┆ 2025-12-0 ┆ 1.7646e9 │
# │ 8000      ┆           ┆ 4         ┆ 8         ┆   ┆           ┆           ┆ 1         ┆          │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ 15:26:18  ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial.transform import Rotation as R

def compare_velocity_methods(imu_df: pl.DataFrame, ins2_df: pl.DataFrame):
    # Alignment and DT calculation
    df = imu_df.join_asof(ins2_df, on="timestamp_ns").interpolate()
    df = df.with_columns([
        ((pl.col("timestamp_ns") - pl.col("timestamp_ns").shift(1)) / 1e9).fill_null(0).alias("dt")
    ])

    acc_raw = df.select(['acc_X_m_s2', 'acc_Y_m_s2', 'acc_Z_m_s2']).to_numpy()
    gyr_raw = df.select(['pqr_P_rad_s', 'pqr_Q_rad_s', 'pqr_R_rad_s']).to_numpy()
    # Using INS2 internal quats for the "Corrected" version
    quats = df.select(['qe2b_x', 'qe2b_y', 'qe2b_z', 'qe2b_w']).to_numpy()
    dts = df['dt'].to_numpy()

    N = len(df)
    g_mag = 9.80665
    g_vec = np.array([0, 0, -g_mag])

    # --- Method 1: Your Provided Code (Open Loop) ---
    vel_open = np.zeros((N, 3))
    curr_rot = R.from_quat([0,0,0,1])
    for i in range(1, N):
        # Orientation update
        delta_rot = R.from_rotvec(gyr_raw[i-1] * dts[i])
        curr_rot = curr_rot * delta_rot
        # Accel transform and integration
        acc_world = curr_rot.apply(acc_raw[i]) - g_vec
        vel_open[i] = vel_open[i-1] + acc_world * dts[i]

    # --- Method 2: ZUPT Corrected ---
    vel_zupt = np.zeros((N, 3))
    for i in range(1, N):
        # Use IMX5 internal orientation (much more stable)
        r = R.from_quat(quats[i])
        acc_world = r.apply(acc_raw[i]) - g_vec
        vel_zupt[i] = vel_zupt[i-1] + acc_world * dts[i]
        
        # ZUPT Trigger (The magic part)
        if np.linalg.norm(gyr_raw[i]) < 0.02 and abs(np.linalg.norm(acc_raw[i]) - g_mag) < 0.1:
            vel_zupt[i] = 0

    # --- Plotting the Comparison ---
    plt.figure(figsize=(12, 6))
    # plt.plot(np.linalg.norm(vel_open, axis=1), label='Your Code (Open Loop)', alpha=0.7)
    plt.plot(np.linalg.norm(vel_zupt, axis=1), label='Corrected (ZUPT)', linewidth=2)
    plt.title("Velocity Comparison: Open-Loop vs. ZUPT")
    plt.ylabel("Velocity Magnitude (m/s)")
    plt.xlabel("Sample Index")
    plt.legend()
    plt.grid(True)
    plt.show()

compare_velocity_methods(flight.raw_data.payload_data['inclinometer']['IMU'], flight.raw_data.payload_data['inclinometer']['INL2'])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(flight.raw_data.drone_data.litchi["unix_timestamp [ms]"]/1e3, flight.raw_data.drone_data.litchi['gimbalPitchRaw']/10)
plt.plot(flight.raw_data.payload_data['inclinometer']['INS']["timestamp_ns"]/1e9, flight.raw_data.payload_data['inclinometer']['INS']["pitch"])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.figure()
plt.plot(flight.raw_data.drone_data.litchi["unix_timestamp [ms]"]/1e3, flight.raw_data.drone_data.litchi['gimbalPitchRaw'])
plt.plot(flight.raw_data.payload_data['inclinometer']['INS']["timestamp_ns"]/1e9, flight.raw_data.payload_data['inclinometer']['INS']["pitch"])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
flight.raw_data.payload_data['inclinometer']['INS']
# Out:
# shape: (102_789, 23)
# ┌────────────┬────────────┬─────────┬─────────┬───┬───────────┬────────────┬───────────┬───────────┐
# │ monotonic_ ┆ timestamp_ ┆ lat_deg ┆ lon_deg ┆ … ┆ pitch     ┆ yaw        ┆ timestamp ┆ datetime  │
# │ ns         ┆ ns         ┆ ---     ┆ ---     ┆   ┆ ---       ┆ ---        ┆ ---       ┆ ---       │
# │ ---        ┆ ---        ┆ f64     ┆ f64     ┆   ┆ f64       ┆ f64        ┆ f64       ┆ datetime[ │
# │ i64        ┆ i64        ┆         ┆         ┆   ┆           ┆            ┆           ┆ ns]       │
# ╞════════════╪════════════╪═════════╪═════════╪═══╪═══════════╪════════════╪═══════════╪═══════════╡
# │ 6536113    ┆ 1764602058 ┆ 0.0     ┆ 0.0     ┆ … ┆ -3.079763 ┆ 123.430063 ┆ 1.7646e9  ┆ 2025-12-0 │
# │            ┆ 764067785  ┆         ┆         ┆   ┆           ┆            ┆           ┆ 1 15:14:1 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 8.7640677 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 85        │
# │ 13537927   ┆ 1764602058 ┆ 0.0     ┆ 0.0     ┆ … ┆ -3.076268 ┆ 123.426912 ┆ 1.7646e9  ┆ 2025-12-0 │
# │            ┆ 771069506  ┆         ┆         ┆   ┆           ┆            ┆           ┆ 1 15:14:1 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 8.7710695 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 06        │
# │ 20479389   ┆ 1764602058 ┆ 0.0     ┆ 0.0     ┆ … ┆ -3.078445 ┆ 123.428459 ┆ 1.7646e9  ┆ 2025-12-0 │
# │            ┆ 778011060  ┆         ┆         ┆   ┆           ┆            ┆           ┆ 1 15:14:1 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 8.7780110 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 60        │
# │ 27512146   ┆ 1764602058 ┆ 0.0     ┆ 0.0     ┆ … ┆ -3.077872 ┆ 123.428459 ┆ 1.7646e9  ┆ 2025-12-0 │
# │            ┆ 785043799  ┆         ┆         ┆   ┆           ┆            ┆           ┆ 1 15:14:1 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 8.7850437 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 99        │
# │ 34458941   ┆ 1764602058 ┆ 0.0     ┆ 0.0     ┆ … ┆ -3.077643 ┆ 123.429891 ┆ 1.7646e9  ┆ 2025-12-0 │
# │            ┆ 791990613  ┆         ┆         ┆   ┆           ┆            ┆           ┆ 1 15:14:1 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 8.7919906 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 13        │
# │ …          ┆ …          ┆ …       ┆ …       ┆ … ┆ …         ┆ …          ┆ …         ┆ …         │
# │ 7194953091 ┆ 1764602778 ┆ 0.0     ┆ 0.0     ┆ … ┆ -4.657918 ┆ -24.251699 ┆ 1.7646e9  ┆ 2025-12-0 │
# │ 77         ┆ 252840849  ┆         ┆         ┆   ┆           ┆            ┆           ┆ 1 15:26:1 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 8.2528408 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 49        │
# │ 7195023785 ┆ 1764602778 ┆ 0.0     ┆ 0.0     ┆ … ┆ -4.648865 ┆ -24.253303 ┆ 1.7646e9  ┆ 2025-12-0 │
# │ 08         ┆ 259910161  ┆         ┆         ┆   ┆           ┆            ┆           ┆ 1 15:26:1 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 8.2599101 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 61        │
# │ 7195093628 ┆ 1764602778 ┆ 0.0     ┆ 0.0     ┆ … ┆ -4.643365 ┆ -24.254106 ┆ 1.7646e9  ┆ 2025-12-0 │
# │ 96         ┆ 266894567  ┆         ┆         ┆   ┆           ┆            ┆           ┆ 1 15:26:1 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 8.2668945 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 67        │
# │ 7195163578 ┆ 1764602778 ┆ 0.0     ┆ 0.0     ┆ … ┆ -4.639354 ┆ -24.25296  ┆ 1.7646e9  ┆ 2025-12-0 │
# │ 57         ┆ 273889529  ┆         ┆         ┆   ┆           ┆            ┆           ┆ 1 15:26:1 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 8.2738895 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 29        │
# │ 7195232515 ┆ 1764602778 ┆ 0.0     ┆ 0.0     ┆ … ┆ -4.631963 ┆ -24.253762 ┆ 1.7646e9  ┆ 2025-12-0 │
# │ 05         ┆ 280783177  ┆         ┆         ┆   ┆           ┆            ┆           ┆ 1 15:26:1 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 8.2807831 │
# │            ┆            ┆         ┆         ┆   ┆           ┆            ┆           ┆ 77        │
# └────────────┴────────────┴─────────┴─────────┴───┴───────────┴────────────┴───────────┴───────────┘
